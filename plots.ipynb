# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame([
    [0.02002/0.09123, 'update', 'JAX', 'VPG'],
    [0.09123/0.09123, 'update', 'Torch', 'VPG'],
    [0.002364/0.004368, 'update', 'JAX', 'TD3'],
    [0.004368/0.004368, 'update', 'Torch', 'TD3'],
], columns=['time (%)', 'Method', 'Framework', 'Algorithm'])
df
# Out:
#    time (%)  Method Framework Algorithm
# 0  0.219445  update       JAX       VPG
# 1  1.000000  update     Torch       VPG
# 2  0.541209  update       JAX       TD3
# 3  1.000000  update     Torch       TD3

# %%
sns.barplot(df, x='Algorithm', y='time (%)', hue='Framework')
# Out:
# <Axes: xlabel='Algorithm', ylabel='time (%)'>
