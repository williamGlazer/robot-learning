# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame([
    [1, 2, 3, 'JAX', 'VPG'],
    [1, 2, 3, 'Torch', 'VPG'],
    [1, 2, 3, 'JAX', 'TD3'],
    [1, 2, 3, 'Torch', 'TD3'],
], columns=['Update (s)', 'Epoch (s)', 'Total (s)', 'Framework', 'Algorithm'])
df
# Out:
#    Update (s)  Epoch (s)  Total (s) Framework Algorithm
# 0           1          2          3       JAX       VPG
# 1           1          2          3     Torch       VPG
# 2           1          2          3       JAX       TD3
# 3           1          2          3     Torch       TD3

# %%
sns.barplot(df, x='Algorithm', y='Update (s)', hue='Framework')
# Out:
# <Axes: xlabel='Algorithm', ylabel='Update (s)'>
